# %% [markdown]
# # Supplementary Material
#
# The paper is accompanied by 7 Jupyter notebooks which are provided in rendered form in this PDF:
#
# - S1: Head models and Forward Modelling
# - S2: Photogrammetric Optode Co-Registration
# - S3: Signal Processing
# - S4: Model-driven (GLM) Analysis
# - S5: DOT - Image Reconstruction
# - S6: Data-Driven (ML) Analysis
# - S7: Data Augmentation
#
# Please use the PDF's document outline to navigate.
#
# Moreover, the notebooks are also hosted on Code Ocean where you can explore them interactively.
#
#   [FIXME Link to example notebooks at Code Ocean](http://cedalion.tools)
#
# To cite any of these notebooks please use the following:
#
#     FIXME DOI issued by Code Ocean
#
# The notebooks are also part of the Cedalion's official documentation, available at
#
#   [http://cedalion.tools/docs](http://cedalion.tools/docs)
